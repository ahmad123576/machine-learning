# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad123576/machine-learning/blob/main/train%26test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/content/car_prices.csv')
df
# Out:
#    Mileage  Age(yrs)  Sell Price($)
# 0    69000         6          18000
# 1    35000         3          34000
# 2    57000         5          26100
# 3    22500         2          40000
# 4    46000         4          31500

# %%
# %matplotlib inline
plt.scatter(df['Mileage'],df['Sell Price($)'])

# %%
plt.scatter(df['Age(yrs)'],df['Sell Price($)'])

# %%
X=df[['Mileage','Age(yrs)']]
X
# Out:
#    Mileage  Age(yrs)
# 0    69000         6
# 1    35000         3
# 2    57000         5
# 3    22500         2
# 4    46000         4

# %%
y=df['Sell Price($)']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test =  train_test_split(X,y,test_size=0.2)

# %%
len(X_train)
# Out:
# 4

# %%
len(X_test)
# Out:
# 1

# %%
len(y_train)
# Out:
# 4

# %%
len(y_test)
# Out:
# 1

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([45383.33333333])

# %%
y_test
# Out:
# 3    40000
# Name: Sell Price($), dtype: int64
