# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad123576/machine-learning/blob/main/logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('/content/insurance.csv')
df.head()
# Out:
#    age  have_insurance
# 0   22               0
# 1   25               0
# 2   47               1
# 3   52               0
# 4   46               1

# %%
plt.scatter(df['age'],df['have_insurance'],color='red', marker='+')

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.have_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 14   49
# 11   28
# 13   29

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
model.predict(X_test)
# Out:
# array([0.60458571, 0.14220677, 0.16422482])

# %%
model.score(X_test,y_test)
# Out:
# 0.6946824788155489

# %%
#lets defined sigmoid fun and do math
import math
def sigmoid(x):
  return 1/(1+math.exp(-x))

# %%
def prediction_fun(age):
  z=0.042*age-1.53
  y=sigmoid(z)
  return y

# %%
age=35
prediction_fun(age)
# Out:
# 0.4850044983805899

# %%
prediction_fun(50)
# Out:
# 0.6387631751488418
