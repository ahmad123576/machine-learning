# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmad123576/machine-learning/blob/main/Naive_titanic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/titanic.csv')
df.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
df.drop(['PassengerId','Name','SibSp','Parch','Ticket','Cabin','Embarked'],axis='columns',inplace=True)
df.head()
# Out:
#    Survived  Pclass     Sex   Age     Fare
# 0         0       3    male  22.0   7.2500
# 1         1       1  female  38.0  71.2833
# 2         1       3  female  26.0   7.9250
# 3         1       1  female  35.0  53.1000
# 4         0       3    male  35.0   8.0500

# %%
target=df.Survived
inputs=df.drop('Survived',axis='columns')

# %%
dummies=pd.get_dummies(inputs.Sex)
dummies.head(3)
# Out:
#    female   male
# 0   False   True
# 1    True  False
# 2    True  False

# %%
inputs=pd.concat([inputs,dummies],axis='columns')
inputs.head(3)
# Out:
#    Pclass     Sex   Age     Fare  female   male
# 0       3    male  22.0   7.2500   False   True
# 1       1  female  38.0  71.2833    True  False
# 2       3  female  26.0   7.9250    True  False

# %%
df.drop('Sex' ,axis='columns',inplace=True)
df.head(3)
# Out:
#    Survived  Pclass   Age     Fare
# 0         0       3  22.0   7.2500
# 1         1       1  38.0  71.2833
# 2         1       3  26.0   7.9250

# %%
# inputs.Sex = inputs.Sex.map({'male': 1, 'female': 2})

# %%
inputs.columns[inputs.isna().any()]
inputs.Age[:10]
inputs.Age=inputs.Age.fillna(inputs.Age.mean())
inputs.head()
# Out:
#    Pclass  Sex   Age     Fare  female   male
# 0       3    1  22.0   7.2500   False   True
# 1       1    2  38.0  71.2833    True  False
# 2       3    2  26.0   7.9250    True  False
# 3       1    2  35.0  53.1000    True  False
# 4       3    1  35.0   8.0500   False   True

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(inputs,target,test_size=0.2)

# %%
from sklearn.naive_bayes import GaussianNB
model=GaussianNB()

# %%
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
model.score(X_test,y_test)
# Out:
# 0.8156424581005587

# %%
model.predict(X_test[:10])
# Out:
# array([0, 1, 1, 1, 0, 0, 0, 1, 0, 0])

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[9.94652692e-01, 5.34730784e-03],
#        [7.94337921e-03, 9.92056621e-01],
#        [4.96080709e-04, 9.99503919e-01],
#        [3.42403049e-03, 9.96575970e-01],
#        [9.96032947e-01, 3.96705300e-03],
#        [9.88649275e-01, 1.13507247e-02],
#        [9.96373519e-01, 3.62648095e-03],
#        [4.91980987e-03, 9.95080190e-01],
#        [9.92944240e-01, 7.05575962e-03],
#        [9.95397835e-01, 4.60216544e-03]])

# %%
X_test[:10]
# Out:
#      Pclass  Sex        Age     Fare  female   male
# 731       3    1  11.000000  18.7875   False   True
# 132       3    2  47.000000  14.5000    True  False
# 166       1    2  29.699118  55.0000    True  False
# 161       2    2  40.000000  15.7500    True  False
# 770       3    1  24.000000   9.5000   False   True
# 201       3    1  29.699118  69.5500   False   True
# 798       3    1  30.000000   7.2292   False   True
# 14        3    2  14.000000   7.8542    True  False
# 826       3    1  29.699118  56.4958   False   True
# 163       3    1  17.000000   8.6625   False   True

# %%
#cross validation
from sklearn.model_selection import cross_val_score
cross_val_score(GaussianNB(),X_train,y_train,cv=5)
# Out:
# array([0.76923077, 0.78321678, 0.78873239, 0.74647887, 0.8028169 ])
